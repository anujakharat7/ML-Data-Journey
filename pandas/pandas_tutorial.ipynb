# %%
import pandas as pd

# %%
info = {
    "Name" : ["Abc", "Xyz"],
    "cgpa" : [9.5, 7.5]
}
df = pd.DataFrame(info)
df
# Out:
#   Name  cgpa
# 0  Abc   9.5
# 1  Xyz   7.5

# %%
s = pd.Series([1, 2, 3, 4, 5])
print(s)
print(type(s))

#index based access
print(s[2])
print(s[0])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# <class 'pandas.core.series.Series'>
# 3
# 1

# %%
#labels
s = pd.Series([23, 24, 25], index = ["Adam", "Steve", "Bob"])
print(s)
print(s["Steve"])
print(s[1])
# Out:
# Adam     23
# Steve    24
# Bob      25
# dtype: int64
# 24
# 24
# C:\Users\Anuja Kharat\AppData\Local\Temp\ipykernel_29672\4127695280.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(s[1])

# %%
#Series are homogeneous
s1 = pd.Series([1, 2, 3, "abc"])
print(s1)

#Series perform vectorized operation
s01 = pd.Series([1, 2, 3, 4])
s2 = pd.Series([10, 20, 30, 40])
print(s01 + s2)

#Series have mutable values but immutable size
print(s1[0])
s01[0] = 100
print(s01)
changed_s01 = s01.drop(0)
print(s01)
print(changed_s01)
# Out:
# 0      1
# 1      2
# 2      3
# 3    abc
# dtype: object
# 0    11
# 1    22
# 2    33
# 3    44
# dtype: int64
# 1
# 0    100
# 1      2
# 2      3
# 3      4
# dtype: int64
# 0    100
# 1      2
# 2      3
# 3      4
# dtype: int64
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
#DataFrame
info = {
    "Name" : ["Adam", "Eve", "Bob", "Abc"],
    "Age" : [23,24,25, 20],
    "GPA" : [9.2, 8.7, 8.8, 7.03]
}
df = pd.DataFrame(info)
# print(df, type(df))
# df
#index and columns
# print(df.index, df.columns)
# Out:
# RangeIndex(start=0, stop=4, step=1) Index(['Name', 'Age', 'GPA'], dtype='object')

# %%
#list of lists
df = pd.DataFrame([["Adam", 23], ["steve", 28], ["Jobs", 24]], columns = ["Name", "Age"])
df
# Out:
#     Name  Age
# 0   Adam   23
# 1  steve   28
# 2   Jobs   24

# %%
#Creating DataFrames using Numpy Arrays
import numpy as np

np_arr = np.array([[1, 2, 3], [4, 5, 6]])
df = pd.DataFrame(np_arr, columns = ['A', 'B', 'C'])
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  4  5  6

# %%
#loading csv data
df = pd.read_csv("employee_data.csv")
print(df, type(df))
#loading json data
df1 = pd.read_json("emp.json")
print(df1, type(df1))
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.core.frame.DataFrame'>
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000 <class 'pandas.core.frame.DataFrame'>

# %%
#DataFrame methods
# df.head()
# df.head(2)
# df.tail()
# df.tail(3)
# df.sample(7)
# df.info()
# df.describe()
# df.shape
# df.columns
df.nunique()
# Out:
# ID            10
# Name          10
# Age           10
# Department     4
# Salary        10
# dtype: int64

# %%
df
# Out:
#    ID     Name  Age Department  Salary
# 0   1    Alice   25         HR   55000
# 1   2      Bob   32         IT   72000
# 2   3  Charlie   28    Finance   48000
# 3   4    David   45  Marketing   91000
# 4   5      Eva   38         IT   65000
# 5   6    Frank   29    Finance   50000
# 6   7    Grace   41         HR   82000
# 7   8   Hannah   26  Marketing   47000
# 8   9      Ian   35         IT   75000
# 9  10    Julia   30    Finance   60000

# %%
df = pd.read_csv("air.csv")
df.describe()
# Out:
#            latitude     longitude          pm25          pm10           no2  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean      23.065980     37.655560     40.369131     70.152228     32.055176
# std       26.156536     78.600701     17.647450     24.999440     13.820680
# min      -37.814000   -123.121000      0.025000      0.061000      0.013000
# 25%       12.972000      2.352000     27.904500     53.125500     22.362500
# 50%       29.232000     42.146000     40.286500     69.961000     32.019500
# 75%       41.008000    103.820000     52.436250     87.256500     41.364250
# max       60.170000    174.763000    115.683000    161.810000     90.019000
#
#                 so2            o3            co           aqi   temperature  \
# count  18000.000000  18000.000000  18000.000000  18000.000000  18000.000000
# mean       6.035508     48.065100      0.800595    104.645556     21.510251
# ...

# %%
#selecting columns
# df["city"]
df[["city", "aqi"]]
# Out:
#            city  aqi
# 0      New York  108
# 1      New York   90
# 2      New York   84
# 3      New York  158
# 4      New York   97
# ...         ...  ...
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
# 17998    Zurich   95
# 17999    Zurich   88
#
# [18000 rows x 2 columns]

# %%
#selecting rows - loc, iloc
# df.loc[2]
# df.loc[1500: 1520] #index inclusive
# df.iloc[100]
df.iloc[17980 : 18000] #index exclusive
# Out:
#                         timestamp country    city  latitude  longitude  \
# 17980  2025-11-18 22:25:17.554219      CH  Zurich    47.377      8.542
# 17981  2025-11-18 23:25:17.554219      CH  Zurich    47.377      8.542
# 17982  2025-11-19 00:25:17.554219      CH  Zurich    47.377      8.542
# 17983  2025-11-19 01:25:17.554219      CH  Zurich    47.377      8.542
# 17984  2025-11-19 02:25:17.554219      CH  Zurich    47.377      8.542
# 17985  2025-11-19 03:25:17.554219      CH  Zurich    47.377      8.542
# 17986  2025-11-19 04:25:17.554219      CH  Zurich    47.377      8.542
# 17987  2025-11-19 05:25:17.554219      CH  Zurich    47.377      8.542
# 17988  2025-11-19 06:25:17.554219      CH  Zurich    47.377      8.542
# 17989  2025-11-19 07:25:17.554219      CH  Zurich    47.377      8.542
# 17990  2025-11-19 08:25:17.554219      CH  Zurich    47.377      8.542
# 17991  2025-11-19 09:25:17.554219      CH  Zurich    47.377      8.542
# ...

# %%
#select rows and columns
# df.loc[29, "temperature"]
# df.loc[25:30, ["city", "aqi", "temperature"]]

df.columns
# df.iloc[200, 12]
# df.iloc[23 : 31, 1:4]
# Out:
#    country      city  latitude
# 23      US  New York    40.713
# 24      US  New York    40.713
# 25      US  New York    40.713
# 26      US  New York    40.713
# 27      US  New York    40.713
# 28      US  New York    40.713
# 29      US  New York    40.713
# 30      US  New York    40.713

# %%
#Accessing individual elements
df.at[0, "city"]
df.iat[0, 8]
# Out:
# np.float64(6.539)

# %%
#copy vs view -> while changing any data, make it a copy. Otherwise original data can change
cities = df['city'].copy()
cities[0] = "Mumbai"
df['city']
# cities
# Out:
# 0        New York
# 1        New York
# 2        New York
# 3        New York
# 4        New York
#            ...
# 17995      Zurich
# 17996      Zurich
# 17997      Zurich
# 17998      Zurich
# 17999      Zurich
# Name: city, Length: 18000, dtype: object

# %%
#filtering data
# df[df["aqi"] > 100]

#applying multiple condition
df[(df["aqi"] > 100) &
(df["temperature"] > 30)]
# df[df["temperature"] < 30]
# Out:
#                         timestamp country      city  latitude  longitude  \
# 6      2025-11-05 00:25:17.554219      US  New York    40.713    -74.006
# 7      2025-11-05 01:25:17.554219      US  New York    40.713    -74.006
# 14     2025-11-05 08:25:17.554219      US  New York    40.713    -74.006
# 17     2025-11-05 11:25:17.554219      US  New York    40.713    -74.006
# 25     2025-11-05 19:25:17.554219      US  New York    40.713    -74.006
# ...                           ...     ...       ...       ...        ...
# 17947  2025-11-17 13:25:17.554219      CH    Zurich    47.377      8.542
# 17950  2025-11-17 16:25:17.554219      CH    Zurich    47.377      8.542
# 17975  2025-11-18 17:25:17.554219      CH    Zurich    47.377      8.542
# 17976  2025-11-18 18:25:17.554219      CH    Zurich    47.377      8.542
# 17991  2025-11-19 09:25:17.554219      CH    Zurich    47.377      8.542
#
#          pm25     pm10     no2    so2      o3     co  aqi  temperature  \
# ...

# %%
aqi_data = df[df["aqi"] > 100] [["city", "aqi"]]
aqi_data
# Out:
#            city  aqi
# 0      New York  108
# 3      New York  158
# 6      New York  155
# 7      New York  115
# 8      New York  121
# ...         ...  ...
# 17991    Zurich  104
# 17993    Zurich  153
# 17995    Zurich  103
# 17996    Zurich  105
# 17997    Zurich  122
#
# [9721 rows x 2 columns]

# %%
#pandans preserve the index columns
aqi_data.iloc[0]
aqi_data.loc[0] 
# aqi_data.loc[1] #gives key error -> because indexes and labels are different
aqi_data.loc[8]
# Out:
# city    New York
# aqi          121
# Name: 8, dtype: object

# %%
#using the quesry method (using copy function for safer side)
# df.query("aqi > 100 & temperature > 30").copy()
aqi_val = 100
aqi_val = df.query("aqi > @aqi_val & temperature > 30")[["city", "aqi"]].copy() #using python variable
aqi_val
# Out:
#            city  aqi
# 6      New York  155
# 7      New York  115
# 14     New York  121
# 17     New York  127
# 25     New York  113
# ...         ...  ...
# 17947    Zurich  107
# 17950    Zurich  140
# 17975    Zurich  111
# 17976    Zurich  146
# 17991    Zurich  104
#
# [2384 rows x 2 columns]

# %%
df = pd.read_csv("raw_data.csv")
#Data cleaning - Handling missing value
# df.isnull()
# df.isna()
# df.isnull().sum()
# df.dropna()  #rows containing empty values are dropped
# df.dropna(axis = 1)   #columns containing empty values are dropped
# df.fillna(100)

#creating a copy of dataset and filling only the age column
# clean_data = df.copy()
# mean_age = clean_data["age"].mean()
# clean_data["age"].fillna(mean_age)

# df.ffill()  #forward fill
df.bfill()  #backward fill
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith  34.0  Canada   Female  62000.0
# 3    3          Alex  34.0     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female  51000.0
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6    Ahmed Khan  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     USA     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz  31.0  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
#handling duplicate values
# df.duplicated()
# df[["age", "income"]].duplicated()
# df.drop_duplicates()
df2 = df.copy()
df2.drop_duplicates(inplace = True)
df2
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0

# %%
#handling datatypes and date_time
# df.dtypes

# df2 = df.copy()
# df2 = df.ffill()
# df2["age"] = df2["age"].astype("int32")
# df2["age"]

aqi = pd.read_csv("air.csv")
aqi["timestamp"] = pd.to_datetime(aqi["timestamp"])
aqi["timestamp"]
# aqi["timestamp"].dtypes
# Out:
# 0       2025-11-04 18:25:17.554219
# 1       2025-11-04 19:25:17.554219
# 2       2025-11-04 20:25:17.554219
# 3       2025-11-04 21:25:17.554219
# 4       2025-11-04 22:25:17.554219
#                    ...
# 17995   2025-11-19 13:25:17.554219
# 17996   2025-11-19 14:25:17.554219
# 17997   2025-11-19 15:25:17.554219
# 17998   2025-11-19 16:25:17.554219
# 17999   2025-11-19 17:25:17.554219
# Name: timestamp, Length: 18000, dtype: datetime64[ns]

# %%
#handling string values
# df["gender"].str.upper()
# df["gender"].str.capitalize()

# df["name"].str.split(" ")

# df["country"].str.contains("USA")
# df["country"].str.contains("india", case = False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[26], line 7
#       1 #handling string values
#       2 # df["gender"].str.upper()
#       3 # df["gender"].str.capitalize()
#       4
#       5 # df["name"].str.split(" ")
#       6 email = "anuja@gmail.com"
# ----> 7 print(email.str.split("@"))
#       9 # df["country"].str.contains("USA")
#      10 # df["country"].str.contains("india", case = False)
#
# AttributeError: 'str' object has no attribute 'str'

# %%
df
# Out:
#     id          name   age country   gender   income
# 0    1      John Doe  29.0     USA     Male  55000.0
# 1    1      John Doe  29.0     USA     Male  55000.0
# 2    2    Jane Smith   NaN  Canada   Female  62000.0
# 3    3          Alex   NaN     USA  Unknown  47000.0
# 4    4  Maria Garcia  34.0   Spain   Female      NaN
# 5    5        Li Wei  27.0   China     Male  51000.0
# 6    6           NaN  45.0   India   Female  73000.0
# 7    7    Ahmed Khan  38.0     NaN     Male  68000.0
# 8    8    Rachel Lee  29.0     USA   Female  62000.0
# 9    9   Carlos Ruiz   NaN  Mexico     Male  45000.0
# 10  10   Emily Davis  31.0     USA      NaN  58000.0
